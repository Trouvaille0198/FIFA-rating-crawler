# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
pd.set_option('display.max_rows',1000)
pd.set_option('display.max_columns',1000)
from matplotlib.font_manager import FontProperties
myfont=FontProperties(fname=r'C:\Windows\Fonts\simhei.ttf',size=14)
sns.set(font=myfont.get_name())

# %%
data=pd.read_csv('../Data/players_info/players_info.csv')
data.head(10)
# Out:
#                                   Name       Nation                 Club  \
# 0       Lionel Andrés Messi Cuccittini    Argentina         FC Barcelona
# 1                   Robert Lewandowski       Poland    FC Bayern München
# 2  Cristiano Ronaldo dos Santos Aveiro     Portugal             Juventus
# 3                      Kevin De Bruyne      Belgium      Manchester City
# 4        Neymar da Silva Santos Júnior       Brazil  Paris Saint-Germain
# 5                 Kylian Mbappé Lottin       France  Paris Saint-Germain
# 6                  Mohamed Salah Ghaly        Egypt            Liverpool
# 7                      Virgil van Dijk  Netherlands            Liverpool
# 8                       Joshua Kimmich      Germany    FC Bayern München
# 9                           Sadio Mané      Senegal            Liverpool
#
#   Position  Age       Birth  Height  Weight  Jersey number Strong feet  \
# 0       RW   33  1987-06-24     170      72           10.0        Left
# ...

# %%
data.duplicated().sum()
# Out:
# 2130

# %%
data=data.drop_duplicates()
data=data.query("Position!='GK'")

# %%
data.describe()
# Out:
#                 Age        Height        Weight  Jersey number          Value  \
# count  16741.000000  16741.000000  16741.000000   16733.000000   16530.000000
# mean      24.680545    179.858969     73.863449      21.243531    3004.290381
# std        4.629780      6.447138      6.681345      17.353476    7747.696870
# min       16.000000    154.000000     48.000000       1.000000      20.000000
# 25%       21.000000    175.000000     69.000000       9.000000     525.000000
# 50%       24.000000    180.000000     74.000000      18.000000    1000.000000
# 75%       28.000000    185.000000     78.000000      28.000000    2200.000000
# max       53.000000    203.000000    110.000000      99.000000  185500.000000
#
#                Wage  Release clause        Rating     Potential          PACE  \
# count  16537.000000    15222.000000  16741.000000  16741.000000  16741.000000
# mean       9.329983     5675.365852     65.946001     71.173466     68.014097
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16741 entries, 0 to 16850
# Data columns (total 50 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 16741 non-null  object
#  1   Nation               16741 non-null  object
#  2   Club                 16733 non-null  object
#  3   Position             16741 non-null  object
#  4   Age                  16741 non-null  int64
#  5   Birth                16741 non-null  object
#  6   Height               16741 non-null  int64
#  7   Weight               16741 non-null  int64
#  8   Jersey number        16733 non-null  float64
#  9   Strong feet          16741 non-null  object
#  10  Value                16530 non-null  float64
#  11  Wage                 16537 non-null  float64
#  12  Release clause       15222 non-null  float64
#  13  Rating               16741 non-null  int64
#  14  Potential            16741 non-null  int64
# ...

# %%
sns.displot(x=data['Age'],bins=38)

# %%
sns.displot(x=data['Height'],bins=20)

# %%
sns.catplot(x='Position',data=data[:],kind='count')

# %%
def position_classify(row):
    if(row['Position']=='ST'):
        return '中锋'
    elif(row['Position']=='CAM'):
        return '前腰'
    elif(row['Position']=='LW' or row['Position']=='RW' or row['Position']=='CF' or row['Position']=='LM' or row['Position']=='RM'):
        return '边锋'
    elif(row['Position']=='CM'):
        return '中场'
    elif(row['Position']=='CDM'):
        return '后腰'
    elif(row['Position']=='CB'):
        return '中后卫'
    elif(row['Position']=='LB' or row['Position']=='RB' or row['Position']=='LWB' or row['Position']=='RWB'):
        return '边后卫'
    else:
        return '?'

# %%
s=data.apply(lambda row:position_classify(row),axis=1)

# %%
data_simple=data[['Position','PACE','SHOOTING','PASSING','DRIBBLING','DEFENCE','PHYSICAL']]

# %%
data['位置']=s
data_simple['位置']=s
# Out:
# <ipython-input-175-88c9328037a3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_simple['位置']=s

# %%
data_simple.to_csv('../Data/players_info/players_info_classified.csv',index=False,encoding='utf-8-sig')

# %%
data_compare=data_simple.query("位置=='中锋' or 位置=='边锋' or 位置=='中场' or 位置=='中后卫' or 位置=='边后卫'")

# %%
sns.pairplot(data_compare,hue='位置')

# %%
data_compare2=data_simple.query("位置=='中锋' or 位置=='中场' or 位置=='中后卫'")
sns.pairplot(data_compare2,hue='位置')
