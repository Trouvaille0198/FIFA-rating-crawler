# %%
# 用knn预测球员司职分类
import pandas as pd
import numpy as np
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
data=pd.read_csv('../Data/players_info/players_info_classified.csv')
data=data.dropna(how='any')
data.head()
# Out:
#   Position     Value  Rating  PACE  SHOOTING  PASSING  DRIBBLING  DEFENCE  \
# 0       RW  103500.0      93    85        92       91         95       38
# 1       ST  124500.0      92    78        92       79         85       44
# 2       ST   63000.0      92    89        93       81         89       35
# 3       CM  127500.0      91    76        86       93         88       64
# 4       LW  132000.0      91    91        85       86         94       36
#
#    PHYSICAL  位置
# 0        65  边锋
# 1        82  中锋
# 2        77  中锋
# 3        78  中场
# 4        58  边锋

# %%
# 对五个位置进行分类预测
data_test=data.query("位置=='中锋' or 位置=='边锋' or 位置=='中场' or 位置=='中后卫' or 位置=='边后卫'")
x=data_test.drop(['位置','Position'],axis=1)
y=data_test['位置'].to_list()

# 划分数据集
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=82)
# 标准化
transfer_std = StandardScaler()
x_train_std = transfer_std.fit_transform(x_train)
x_test_std = transfer_std.transform(x_test)  # 测试集不要用fit, 因为要保持和训练集处理方式一致
# KNN
estimator_knn = KNeighborsClassifier()
# 调优
param_dict = {"n_neighbors": [i for i in range(1,20)]}
estimator_knn = GridSearchCV(
    estimator_knn, param_grid=param_dict, cv=10)  # 10折
# 训练模型
estimator_knn.fit(x_train_std, y_train)
y_pred = estimator_knn.predict(x_test_std)

print("准确率为：\n", estimator_knn.score(x_test_std, y_test))
print("最佳估计器:\n", estimator_knn.best_estimator_)
# Out:
# 准确率为：
#  0.8257488479262672
# 最佳估计器:
#  KNeighborsClassifier(n_neighbors=16)

# %%
# 对三个位置进行分类预测
data_test=data.query("位置=='中锋' or 位置=='中场' or 位置=='中后卫'")

x=data_test.drop(['位置','Position'],axis=1)
y=data_test['位置'].to_list()

# 划分数据集
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=2)
# 标准化
transfer_std = StandardScaler()
x_train_std = transfer_std.fit_transform(x_train)
x_test_std = transfer_std.transform(x_test)  # 测试集不要用fit, 因为要保持和训练集处理方式一致
# KNN
estimator_knn = KNeighborsClassifier()
# 调优
param_dict = {"n_neighbors": [i for i in range(1,20)]}
estimator_knn = GridSearchCV(
    estimator_knn, param_grid=param_dict, cv=10)  # 10折
# 训练模型
estimator_knn.fit(x_train_std, y_train)
y_pred = estimator_knn.predict(x_test_std)


print("准确率为：\n", estimator_knn.score(x_test_std, y_test))
print("最佳估计器:\n", estimator_knn.best_estimator_)
# Out:
# 准确率为：
#  0.9726720647773279
# 最佳估计器:
#  KNeighborsClassifier()
